# %% [markdown]
# Import des dépendances

# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# Connexion : Création du lien entre Python et la base PostgreSQL via SQLAlchemy.

# %%
# Connexion PostgreSQL
engine = create_engine('postgresql://csgo_user:csgo_pass@localhost:5432/csgo_db')

# %% [markdown]
# Optimisation RAM : Utilisation de chunksize=10000 pour charger les données par petits paquets et ne pas saturer la mémoire du PC.
#
# Robustesse : Forçage du type dtype=str pour accepter toutes les données brutes (même les erreurs de saisie comme le "o") sans faire planter l'importation.
#
# Chargement : Importation automatique des 4 fichiers CSV vers des tables brutes (RAW) dans PostgreSQL.

# %%
# Liste des CSV à charger
files = [('results.csv','results'), ('players.csv','players'), 
         ('picks.csv','picks'), ('economy.csv','economy')]

for csv_file, table_name in files:
    print(f"Chargement de {table_name}...")
    
    # dtype=str évite les erreurs de type (ex: le "o" dans best_of)
    # chunksize=10000
    with pd.read_csv(f'data/{csv_file}', chunksize=10000, dtype=str, low_memory=False) as reader:
        first = True
        for chunk in reader:
            mode = 'replace' if first else 'append'
            chunk.to_sql(table_name, engine, if_exists=mode, index=False)
            first = False
# Out:
# Chargement de results...
# Chargement de players...
# Chargement de picks...
# Chargement de economy...

# %% [markdown]
# Audit des donnees
#
#
# Inspection : Requête sur le schéma information_schema pour lister précisément les noms des colonnes importées.
#
# Validation : Permet de vérifier les noms réels (ex: _map ou player_name) avant d'écrire les requêtes de transformation SQL.

# %%
from sqlalchemy import text

with engine.connect() as conn:
    # Cette requête liste toutes les tables et leurs colonnes
    result = conn.execute(text("""
        SELECT table_name, column_name 
        FROM information_schema.columns 
        WHERE table_schema = 'public'
        ORDER BY table_name;
    """))
    
    for row in result:
        print(f"Table: {row[0]} | Colonne: {row[1]}")
# Out:
# Table: dim_matches | Colonne: date
# Table: dim_matches | Colonne: match_id
# Table: dim_matches | Colonne: team_2
# Table: dim_matches | Colonne: team_1
# Table: dim_matches | Colonne: match_winner
# Table: dim_players | Colonne: player_name
# Table: dim_players | Colonne: player_id
# Table: dim_players | Colonne: country
# Table: economy | Colonne: 20_winner
# Table: economy | Colonne: 24_t1
# Table: economy | Colonne: 8_t1
# Table: economy | Colonne: 22_t1
# Table: economy | Colonne: 18_t2
# Table: economy | Colonne: 13_t1
# Table: economy | Colonne: 10_t2
# Table: economy | Colonne: 17_winner
# Table: economy | Colonne: date
# Table: economy | Colonne: 19_t2
# Table: economy | Colonne: 9_t1
# Table: economy | Colonne: 25_t1
# Table: economy | Colonne: 3_t1
# Table: economy | Colonne: 1_t1
# Table: economy | Colonne: 23_winner
# Table: economy | Colonne: 29_winner
# Table: economy | Colonne: 14_t2
# Table: economy | Colonne: 25_t2
# Table: economy | Colonne: 5_t2
# Table: economy | Colonne: 2_winner
# Table: economy | Colonne: 14_t1
# Table: economy | Colonne: 27_t1
# Table: economy | Colonne: match_id
# Table: economy | Colonne: team_1
# Table: economy | Colonne: 3_winner
# Table: economy | Colonne: 15_t2
# Table: economy | Colonne: 11_t1
# Table: economy | Colonne: 17_t1
# Table: economy | Colonne: 13_winner
# Table: economy | Colonne: 16_t1
# Table: economy | Colonne: 18_t1
# Table: economy | Colonne: 7_t1
# Table: economy | Colonne: 24_winner
# Table: economy | Colonne: 27_winner
# Table: economy | Colonne: 26_t2
# Table: economy | Colonne: 13_t2
# Table: economy | Colonne: 28_t1
# Table: economy | Colonne: 10_t1
# Table: economy | Colonne: 9_winner
# Table: economy | Colonne: _map
# Table: economy | Colonne: 16_winner
# Table: economy | Colonne: 23_t1
# Table: economy | Colonne: 19_winner
# Table: economy | Colonne: 15_t1
# Table: economy | Colonne: 29_t1
# Table: economy | Colonne: t2_start
# Table: economy | Colonne: 24_t2
# Table: economy | Colonne: 16_t2
# Table: economy | Colonne: 26_t1
# Table: economy | Colonne: 29_t2
# Table: economy | Colonne: 5_t1
# Table: economy | Colonne: 8_t2
# Table: economy | Colonne: 8_winner
# Table: economy | Colonne: event_id
# Table: economy | Colonne: 4_winner
# Table: economy | Colonne: 18_winner
# Table: economy | Colonne: 22_t2
# Table: economy | Colonne: 4_t2
# Table: economy | Colonne: 7_t2
# Table: economy | Colonne: 14_winner
# Table: economy | Colonne: 28_winner
# Table: economy | Colonne: 6_t1
# Table: economy | Colonne: 1_t2
# Table: economy | Colonne: 17_t2
# Table: economy | Colonne: 4_t1
# Table: economy | Colonne: 22_winner
# Table: economy | Colonne: team_2
# Table: economy | Colonne: 12_t1
# Table: economy | Colonne: 28_t2
# Table: economy | Colonne: 11_t2
# Table: economy | Colonne: 7_winner
# Table: economy | Colonne: 30_t2
# Table: economy | Colonne: 23_t2
# Table: economy | Colonne: 25_winner
# Table: economy | Colonne: 12_t2
# Table: economy | Colonne: 19_t1
# Table: economy | Colonne: 3_t2
# Table: economy | Colonne: 9_t2
# Table: economy | Colonne: 30_winner
# Table: economy | Colonne: 21_winner
# Table: economy | Colonne: 26_winner
# Table: economy | Colonne: 21_t1
# Table: economy | Colonne: 20_t2
# Table: economy | Colonne: 12_winner
# Table: economy | Colonne: 10_winner
# Table: economy | Colonne: 5_winner
# Table: economy | Colonne: t1_start
# Table: economy | Colonne: 15_winner
# Table: economy | Colonne: 2_t2
# Table: economy | Colonne: 11_winner
# Table: economy | Colonne: 6_winner
# Table: economy | Colonne: 20_t1
# Table: economy | Colonne: best_of
# Table: economy | Colonne: 2_t1
# Table: economy | Colonne: 30_t1
# Table: economy | Colonne: 6_t2
# Table: economy | Colonne: 27_t2
# Table: economy | Colonne: 1_winner
# Table: economy | Colonne: 21_t2
# Table: fact_matches | Colonne: date
# Table: fact_matches | Colonne: team_2
# Table: fact_matches | Colonne: result_1
# Table: fact_matches | Colonne: match_winner
# Table: fact_matches | Colonne: result_2
# Table: fact_matches | Colonne: _map
# Table: fact_matches | Colonne: match_id
# Table: fact_matches | Colonne: team_1
# Table: fact_player_stats | Colonne: deaths
# Table: fact_player_stats | Colonne: flash_assists
# Table: fact_player_stats | Colonne: kast
# Table: fact_player_stats | Colonne: stats_id
# Table: fact_player_stats | Colonne: fkdiff
# Table: fact_player_stats | Colonne: kills
# Table: fact_player_stats | Colonne: map_name
# Table: fact_player_stats | Colonne: player_team
# Table: fact_player_stats | Colonne: assists
# Table: fact_player_stats | Colonne: adr
# Table: fact_player_stats | Colonne: headshots
# Table: fact_player_stats | Colonne: rating
# Table: fact_player_stats | Colonne: player_id
# Table: fact_player_stats | Colonne: kddiff
# Table: fact_player_stats | Colonne: opponent
# Table: fact_player_stats | Colonne: match_id
# Table: map | Colonne: id_map
# Table: map | Colonne: map_name
# Table: match | Colonne: id_map
# Table: match | Colonne: id_match
# Table: match | Colonne: match_date
# Table: picks | Colonne: system
# Table: picks | Colonne: best_of
# Table: picks | Colonne: match_id
# Table: picks | Colonne: date
# Table: picks | Colonne: event_id
# Table: picks | Colonne: left_over
# Table: picks | Colonne: t2_removed_1
# Table: picks | Colonne: t1_removed_2
# Table: picks | Colonne: t1_removed_1
# Table: picks | Colonne: team_1
# Table: picks | Colonne: inverted_teams
# Table: picks | Colonne: t2_picked_1
# Table: picks | Colonne: team_2
# Table: picks | Colonne: t1_picked_1
# Table: picks | Colonne: t2_removed_2
# Table: picks | Colonne: t2_removed_3
# Table: picks | Colonne: t1_removed_3
# Table: player | Colonne: country
# Table: player | Colonne: player_name
# Table: player | Colonne: id_player
# Table: players | Colonne: m3_kills
# Table: players | Colonne: rating
# Table: players | Colonne: m2_kddiff
# Table: players | Colonne: kddiff_ct
# Table: players | Colonne: deaths
# Table: players | Colonne: m1_rating_t
# Table: players | Colonne: kills_ct
# Table: players | Colonne: m1_deaths_t
# Table: players | Colonne: m3_deaths
# Table: players | Colonne: m1_kast_ct
# Table: players | Colonne: m3_assists
# Table: players | Colonne: assists
# Table: players | Colonne: kills_t
# Table: players | Colonne: m2_rating_ct
# Table: players | Colonne: m1_adr_t
# Table: players | Colonne: kast_ct
# Table: players | Colonne: date
# Table: players | Colonne: m3_kast
# Table: players | Colonne: fkdiff
# Table: players | Colonne: m2_kddiff_t
# Table: players | Colonne: m1_kills
# Table: players | Colonne: m3_kddiff
# Table: players | Colonne: m3_adr
# Table: players | Colonne: m1_kast_t
# Table: players | Colonne: m1_adr_ct
# Table: players | Colonne: m3_kast_t
# Table: players | Colonne: m1_deaths_ct
# Table: players | Colonne: m2_kills_t
# Table: players | Colonne: m1_kddiff_t
# Table: players | Colonne: m2_kills_ct
# Table: players | Colonne: m1_kast
# Table: players | Colonne: player_id
# Table: players | Colonne: m2_adr
# Table: players | Colonne: m2_deaths_ct
# Table: players | Colonne: m2_adr_ct
# Table: players | Colonne: rating_ct
# Table: players | Colonne: m2_fkdiff
# Table: players | Colonne: m1_fkdiff
# Table: players | Colonne: kddiff
# Table: players | Colonne: m2_kills
# Table: players | Colonne: best_of
# Table: players | Colonne: map_2
# Table: players | Colonne: m1_rating_ct
# Table: players | Colonne: m1_kills_t
# Table: players | Colonne: player_name
# Table: players | Colonne: m1_hs
# Table: players | Colonne: kast_t
# Table: players | Colonne: map_1
# Table: players | Colonne: m3_adr_ct
# Table: players | Colonne: m2_kast
# Table: players | Colonne: m2_kast_ct
# Table: players | Colonne: m1_assists
# Table: players | Colonne: m1_adr
# Table: players | Colonne: m1_deaths
# Table: players | Colonne: kills
# Table: players | Colonne: adr_ct
# Table: players | Colonne: m2_assists
# Table: players | Colonne: m2_rating
# Table: players | Colonne: m2_rating_t
# Table: players | Colonne: m1_kills_ct
# Table: players | Colonne: team
# Table: players | Colonne: m2_adr_t
# Table: players | Colonne: deaths_t
# Table: players | Colonne: m2_kast_t
# Table: players | Colonne: m1_rating
# Table: players | Colonne: hs
# Table: players | Colonne: m3_deaths_ct
# Table: players | Colonne: map_3
# Table: players | Colonne: match_id
# Table: players | Colonne: country
# Table: players | Colonne: adr_t
# Table: players | Colonne: event_name
# Table: players | Colonne: m2_deaths
# Table: players | Colonne: opponent
# Table: players | Colonne: adr
# Table: players | Colonne: m3_kddiff_ct
# Table: players | Colonne: m3_hs
# Table: players | Colonne: m3_rating
# Table: players | Colonne: m2_deaths_t
# Table: players | Colonne: m1_flash_assists
# Table: players | Colonne: m3_kast_ct
# Table: players | Colonne: m2_flash_assists
# Table: players | Colonne: m3_adr_t
# Table: players | Colonne: m3_flash_assists
# Table: players | Colonne: m3_rating_ct
# Table: players | Colonne: m1_kddiff
# Table: players | Colonne: kddiff_t
# Table: players | Colonne: deaths_ct
# Table: players | Colonne: event_id
# Table: players | Colonne: m1_kddiff_ct
# Table: players | Colonne: m2_kddiff_ct
# Table: players | Colonne: m3_kills_t
# Table: players | Colonne: kast
# Table: players | Colonne: m3_fkdiff
# Table: players | Colonne: m3_deaths_t
# Table: players | Colonne: rating_t
# Table: players | Colonne: m2_hs
# Table: players | Colonne: m3_kddiff_t
# Table: players | Colonne: flash_assists
# Table: players | Colonne: m3_kills_ct
# Table: players | Colonne: m3_rating_t
# Table: results | Colonne: rank_1
# Table: results | Colonne: team_1
# Table: results | Colonne: map_winner
# Table: results | Colonne: result_2
# Table: results | Colonne: t_1
# Table: results | Colonne: ct_2
# Table: results | Colonne: t_2
# Table: results | Colonne: rank_2
# Table: results | Colonne: date
# Table: results | Colonne: map_wins_1
# Table: results | Colonne: map_wins_2
# Table: results | Colonne: team_2
# Table: results | Colonne: starting_ct
# Table: results | Colonne: match_id
# Table: results | Colonne: ct_1
# Table: results | Colonne: match_winner
# Table: results | Colonne: result_1
# Table: results | Colonne: _map
# Table: results | Colonne: event_id
# Table: team | Colonne: id_team
# Table: team | Colonne: team_name

# %% [markdown]
# L'objectif est de passer d'un modele plat (fichiers CSV volumineux et redondants) à un schema en etoile performant.
# Cela permet de separer les donnees descriptives des donnees de performance.

# %%
with engine.connect() as conn:
    conn.execute(text("""
        DROP TABLE IF EXISTS player CASCADE;
        CREATE TABLE player (
            id_player INTEGER PRIMARY KEY,
            player_name VARCHAR(255),
            country VARCHAR(100)
        );

        INSERT INTO player (id_player, player_name, country)
        SELECT DISTINCT 
            CAST(NULLIF(TRIM(player_id), '') AS INTEGER),
            player_name,
            country
        FROM players
        WHERE player_id IS NOT NULL 
          AND TRIM(player_id) != ''
          AND TRIM(player_id) ~ '^[0-9]+$'
        ON CONFLICT (id_player) DO NOTHING;
    """))
    conn.commit()

# %%
with engine.connect() as conn:
    conn.execute(text("""
        DROP TABLE IF EXISTS map CASCADE;
        CREATE TABLE map (
            id_map SERIAL PRIMARY KEY,
            map_name VARCHAR(100) UNIQUE NOT NULL
        );

        INSERT INTO map (map_name)
        SELECT DISTINCT map_name
        FROM (
            SELECT COALESCE(map_1, map_2, map_3) AS map_name
            FROM players
            WHERE COALESCE(map_1, map_2, map_3) IS NOT NULL
            UNION
            SELECT DISTINCT _map AS map_name FROM results WHERE _map IS NOT NULL
            UNION
            SELECT DISTINCT _map AS map_name FROM economy WHERE _map IS NOT NULL
        ) sub
        WHERE map_name IS NOT NULL AND map_name != ''
        ON CONFLICT (map_name) DO NOTHING;
    """))
    conn.commit()

# %%
with engine.connect() as conn:
    conn.execute(text("""
        DROP TABLE IF EXISTS team CASCADE;
        CREATE TABLE team (
            id_team SERIAL PRIMARY KEY,
            team_name VARCHAR(255) UNIQUE NOT NULL
        );

        INSERT INTO team (team_name)
        SELECT DISTINCT team_name
        FROM (
            SELECT team_1 AS team_name FROM results
            UNION
            SELECT team_2 AS team_name FROM results
            UNION
            SELECT team AS team_name FROM players
            UNION
            SELECT opponent AS team_name FROM players
        ) sub
        WHERE team_name IS NOT NULL AND team_name != ''
        ON CONFLICT (team_name) DO NOTHING;
    """))
    conn.commit()

# %%
with engine.connect() as conn:
    conn.execute(text("""
        DROP TABLE IF EXISTS player_team_match CASCADE;
        CREATE TABLE player_team_match (
            id_player INTEGER,
            id_team INTEGER,
            id_match INTEGER,
            kills INTEGER,
            deaths INTEGER,
            assists INTEGER,
            rating NUMERIC,
            adr NUMERIC,
            kast NUMERIC,
            kddiff INTEGER,
            headshots INTEGER,
            fkdiff INTEGER,
            flash_assists INTEGER,
            PRIMARY KEY (id_player, id_team, id_match),
            FOREIGN KEY (id_player) REFERENCES player(id_player),
            FOREIGN KEY (id_team, id_match) REFERENCES team_match(id_team, id_match)
        );

        INSERT INTO player_team_match (
            id_player, id_team, id_match, kills, deaths, assists, rating, 
            adr, kast, kddiff, headshots, fkdiff, flash_assists
        )
        SELECT 
            CAST(NULLIF(TRIM(p.player_id), '') AS INTEGER),
            t.id_team,
            CAST(NULLIF(TRIM(p.match_id), '') AS INTEGER),
            CASE WHEN TRIM(COALESCE(p.kills::TEXT, '')) ~ '^[0-9]+$' THEN CAST(p.kills AS INTEGER) ELSE NULL END,
            CASE WHEN TRIM(COALESCE(p.deaths::TEXT, '')) ~ '^[0-9]+$' THEN CAST(p.deaths AS INTEGER) ELSE NULL END,
            CASE WHEN TRIM(COALESCE(p.assists::TEXT, '')) ~ '^[0-9]+$' THEN CAST(p.assists AS INTEGER) ELSE NULL END,
            CASE WHEN TRIM(COALESCE(p.rating::TEXT, '')) ~ '^[0-9]*\.?[0-9]+$' THEN CAST(p.rating AS NUMERIC) ELSE NULL END,
            CASE WHEN TRIM(COALESCE(p.adr::TEXT, '')) ~ '^[0-9]*\.?[0-9]+$' THEN CAST(p.adr AS NUMERIC) ELSE NULL END,
            CASE WHEN TRIM(COALESCE(p.kast::TEXT, '')) ~ '^[0-9]*\.?[0-9]+$' THEN CAST(p.kast AS NUMERIC) ELSE NULL END,
            CASE WHEN TRIM(COALESCE(p.kddiff::TEXT, '')) ~ '^-?[0-9]+$' THEN CAST(p.kddiff AS INTEGER) ELSE NULL END,
            CASE WHEN TRIM(COALESCE(p.hs::TEXT, '')) ~ '^[0-9]+$' THEN CAST(p.hs AS INTEGER) ELSE NULL END,
            CASE WHEN TRIM(COALESCE(p.fkdiff::TEXT, '')) ~ '^-?[0-9]+$' THEN CAST(p.fkdiff AS INTEGER) ELSE NULL END,
            CASE WHEN TRIM(COALESCE(p.flash_assists::TEXT, '')) ~ '^[0-9]+$' THEN CAST(p.flash_assists AS INTEGER) ELSE NULL END
        FROM players p
        JOIN team t ON t.team_name = p.team
        JOIN team_match tm ON tm.id_team = t.id_team AND tm.id_match = CAST(NULLIF(TRIM(p.match_id), '') AS INTEGER)
        WHERE p.player_id IS NOT NULL 
          AND TRIM(p.player_id) != ''
          AND TRIM(p.player_id) ~ '^[0-9]+$'
          AND p.match_id IS NOT NULL 
          AND TRIM(p.match_id) != ''
          AND TRIM(p.match_id) ~ '^[0-9]+$'
        ON CONFLICT (id_player, id_team, id_match) DO NOTHING;
    """))
    conn.commit()

# %%
with engine.connect() as conn:
    conn.execute(text("""
        CREATE INDEX IF NOT EXISTS idx_team_match_team ON team_match(id_team);
        CREATE INDEX IF NOT EXISTS idx_team_match_match ON team_match(id_match);
        
        CREATE INDEX IF NOT EXISTS idx_player_team_match_player ON player_team_match(id_player);
        CREATE INDEX IF NOT EXISTS idx_player_team_match_team ON player_team_match(id_team);
        CREATE INDEX IF NOT EXISTS idx_player_team_match_match ON player_team_match(id_match);
        
        CREATE INDEX IF NOT EXISTS idx_match_date ON match(match_date);
        CREATE INDEX IF NOT EXISTS idx_match_map ON match(id_map);
    """))
    conn.commit()

# %% [markdown]
# Cardinalités
#
# Un joueur peut participer à plusieurs matchs (1,N)
# Une équipe peut jouer plusieurs matchs (1,N)
# Un match se joue sur une carte (1,1)
# Un match implique deux équipes via team_match (2,2)
# Chaque participation de joueur est liée à une équipe et un match via team_match

# %% [markdown]
# Sur le lien localhost:8080 et en utilisant les credentials suivant : epsi@gmail.com | azerty1234!

# %% [markdown]
# Le tableau de bord CS GO Stats contiendra le Top 10 des joueurs avec les statistiques d'élimination par partie ainsi que les éliminations par pays.
